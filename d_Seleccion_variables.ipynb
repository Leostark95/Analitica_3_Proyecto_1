# %% [markdown]
# ## Librerías

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression,  f_classif, mutual_info_classif, chi2
from sklearn.preprocessing import MinMaxScaler

import pandas as pd
import a_funciones as funciones

# %% [markdown]
# ## Importación de datos

# %%
# Manuela 
# Datos del 2015
df_2015 = pd.read_csv("C:\\Users\\Manuela\\Documents\\Analitica 3\\Analitica_3_Proyecto_1\\processed_data_2015.csv", sep =",")
# Datos del 2016
df_2016 = pd.read_csv("C:\\Users\Manuela\\Documents\\Analitica 3\\Analitica_3_Proyecto_1\\processed_data_2016.csv", sep =",")

# %%
df_2015['EmployeeID'] = df_2015['EmployeeID'].astype(str)
df_2015['PercentSalaryHike'] = df_2015['PercentSalaryHike'] / 100

# %% [markdown]
# Dumizar variables categóricas

# %%
df_2015['EnvironmentSatisfaction'] = df_2015['EnvironmentSatisfaction'].astype(str)
df_2015['JobSatisfaction'] = df_2015['JobSatisfaction'].astype(str)
df_2015['WorkLifeBalance'] = df_2015['WorkLifeBalance'].astype(str)
df_2015['JobInvolvement'] = df_2015['JobInvolvement'].astype(str)
df_2015['PerformanceRating'] = df_2015['PerformanceRating'].astype(str)
df_2015['NumCompaniesWorked'] = df_2015['NumCompaniesWorked'].astype(int)
df_2015['Education'] = df_2015['Education'].astype(str)

# %%
columnas_dumizar = ['BusinessTravel', 'Department', 'JobRole', 'EnvironmentSatisfaction',
                    'JobSatisfaction', 'WorkLifeBalance', 'JobInvolvement', 'Education']


df_dummy = pd.get_dummies(df_2015[columnas_dumizar])
df_dummy.head()
# Out:
#    BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                      False                             False
# 1                      False                              True
# 2                      False                              True
# 3                       True                             False
# 4                      False                             False
#
#    BusinessTravel_Travel_Rarely  Department_Human Resources  \
# 0                          True                       False
# 1                         False                       False
# 2                         False                       False
# 3                         False                       False
# 4                          True                       False
#
#    Department_Research & Development  Department_Sales  \
# 0                              False              True
# 1                               True             False
# 2                               True             False
# 3                               True             False
# 4                               True             False
#
#    JobRole_Healthcare Representative  JobRole_Human Resources  \
# 0                               True                    False
# 1                              False                    False
# 2                              False                    False
# 3                              False                     True
# 4                              False                    False
#
#    JobRole_Laboratory Technician  JobRole_Manager  ...  WorkLifeBalance_4.0  \
# 0                          False            False  ...                False
# 1                          False            False  ...                 True
# 2                          False            False  ...                False
# 3                          False            False  ...                False
# 4                          False            False  ...                False
#
#    JobInvolvement_1  JobInvolvement_2  JobInvolvement_3  JobInvolvement_4  \
# 0             False             False              True             False
# 1             False              True             False             False
# 2             False             False              True             False
# 3             False              True             False             False
# 4             False             False              True             False
#
#    Education_1  Education_2  Education_3  Education_4  Education_5
# 0        False         True        False        False        False
# 1         True        False        False        False        False
# 2        False        False        False         True        False
# 3        False        False        False        False         True
# 4         True        False        False        False        False
#
# [5 rows x 36 columns]

# %%
y = df_2015['renuncia2016']

# %%
x_numeric = df_2015.select_dtypes(int)
del x_numeric['renuncia2016']

# %%
df_normalizada = funciones.normalize_dataframe(x_numeric)
# Out:
# c:\Users\Manuela\Documents\Analitica 3\Analitica_3_Proyecto_1\a_funciones.py:352: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.78571429 0.30952381 0.33333333 ... 0.35714286 0.33333333 0.45238095]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :] = sv
# c:\Users\Manuela\Documents\Analitica 3\Analitica_3_Proyecto_1\a_funciones.py:352: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.17857143 0.32142857 0.57142857 ... 0.         0.78571429 0.03571429]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :] = sv
# c:\Users\Manuela\Documents\Analitica 3\Analitica_3_Proyecto_1\a_funciones.py:352: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.63754608 0.16745656 0.96466561 ... 0.21790416 0.07682991 0.15755661]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :] = sv
# c:\Users\Manuela\Documents\Analitica 3\Analitica_3_Proyecto_1\a_funciones.py:352: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.11111111 0.         0.11111111 ... 0.77777778 0.         0.66666667]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :] = sv
# c:\Users\Manuela\Documents\Analitica 3\Analitica_3_Proyecto_1\a_funciones.py:352: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1.         0.5        0.33333333 ... 0.33333333 0.33333333 0.33333333]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :] = sv
# c:\Users\Manuela\Documents\Analitica 3\Analitica_3_Proyecto_1\a_funciones.py:352: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.025 0.125 0.125 ... 0.225 0.075 0.025]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :] = sv
# c:\Users\Manuela\Documents\Analitica 3\Analitica_3_Proyecto_1\a_funciones.py:352: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.         0.06666667 0.         ... 0.06666667 0.06666667 0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[:, :] = sv

# %%
df_final = pd.concat([df_normalizada, df_dummy], axis=1)
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4308 entries, 0 to 4307
# Data columns (total 43 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                4308 non-null   float64
#  1   DistanceFromHome                   4308 non-null   float64
#  2   MonthlyIncome                      4308 non-null   float64
#  3   NumCompaniesWorked                 4308 non-null   float64
#  4   TrainingTimesLastYear              4308 non-null   float64
#  5   YearsAtCompany                     4308 non-null   float64
#  6   YearsSinceLastPromotion            4308 non-null   float64
#  7   BusinessTravel_Non-Travel          4308 non-null   bool
#  8   BusinessTravel_Travel_Frequently   4308 non-null   bool
#  9   BusinessTravel_Travel_Rarely       4308 non-null   bool
#  10  Department_Human Resources         4308 non-null   bool
#  11  Department_Research & Development  4308 non-null   bool
#  12  Department_Sales                   4308 non-null   bool
#  13  JobRole_Healthcare Representative  4308 non-null   bool
#  14  JobRole_Human Resources            4308 non-null   bool
#  15  JobRole_Laboratory Technician      4308 non-null   bool
#  16  JobRole_Manager                    4308 non-null   bool
#  17  JobRole_Manufacturing Director     4308 non-null   bool
#  18  JobRole_Research Director          4308 non-null   bool
#  19  JobRole_Research Scientist         4308 non-null   bool
#  20  JobRole_Sales Executive            4308 non-null   bool
#  21  JobRole_Sales Representative       4308 non-null   bool
#  22  EnvironmentSatisfaction_1.0        4308 non-null   bool
#  23  EnvironmentSatisfaction_2.0        4308 non-null   bool
#  24  EnvironmentSatisfaction_3.0        4308 non-null   bool
#  25  EnvironmentSatisfaction_4.0        4308 non-null   bool
#  26  JobSatisfaction_1.0                4308 non-null   bool
#  27  JobSatisfaction_2.0                4308 non-null   bool
#  28  JobSatisfaction_3.0                4308 non-null   bool
#  29  JobSatisfaction_4.0                4308 non-null   bool
#  30  WorkLifeBalance_1.0                4308 non-null   bool
#  31  WorkLifeBalance_2.0                4308 non-null   bool
#  32  WorkLifeBalance_3.0                4308 non-null   bool
#  33  WorkLifeBalance_4.0                4308 non-null   bool
#  34  JobInvolvement_1                   4308 non-null   bool
#  35  JobInvolvement_2                   4308 non-null   bool
#  36  JobInvolvement_3                   4308 non-null   bool
#  37  JobInvolvement_4                   4308 non-null   bool
#  38  Education_1                        4308 non-null   bool
#  39  Education_2                        4308 non-null   bool
#  40  Education_3                        4308 non-null   bool
#  41  Education_4                        4308 non-null   bool
#  42  Education_5                        4308 non-null   bool
# dtypes: bool(36), float64(7)
# memory usage: 387.2 KB

# %% [markdown]
# ## Métodos Wrapper

# %% [markdown]
# RFE (Recursive Feature Elimination)

# %%
# Función recursiva de selección de características
def recursive_feature_selection(X,y,model,k): #model=modelo que me va a servir de estimador en este caso de regresión logística
  rfe = RFE(model, n_features_to_select=k, step=1)# step=1 cada cuanto el toma la sucesión de tomar una caracteristica
  fit = rfe.fit(X, y)
  X_new = fit.support_
  print("Num Features: %s" % (fit.n_features_))
  print("Selected Features: %s" % (fit.support_))
  print("Feature Ranking: %s" % (fit.ranking_))

  return X_new

# %%
from sklearn.linear_model import LogisticRegressionCV, Ridge

# %%
#  Estimador en este caso para regresión logística (problema de clasificación)
model = LogisticRegressionCV()

# Obtener columnas seleciconadas - (4 caracteristicas)
X_new = recursive_feature_selection(df_final, y, model, 30)

# Nuevo conjunto de datos
df_new = df_final.iloc[:,X_new]
df_new.head()
# Out:
# Num Features: 30
# Selected Features: [ True False  True  True  True  True  True  True  True False  True  True
#   True  True False  True  True  True  True  True  True False  True False
#  False  True  True  True False  True  True False  True False  True False
#   True  True False  True False False  True]
# Feature Ranking: [ 1 12  1  1  1  1  1  1  1 14  1  1  1  1 13  1  1  1  1  1  1  3  1 11
#  10  1  1  1  2  1  1  5  1  6  1  4  1  1  9  1  7  8  1]
#         Age  MonthlyIncome  NumCompaniesWorked  TrainingTimesLastYear  \
# 0  0.785714       0.637546            0.111111               1.000000
# 1  0.309524       0.167457            0.000000               0.500000
# 2  0.333333       0.964666            0.111111               0.333333
# 3  0.476190       0.385045            0.333333               0.833333
# 4  0.333333       0.070195            0.444444               0.333333
#
#    YearsAtCompany  YearsSinceLastPromotion  BusinessTravel_Non-Travel  \
# 0           0.025                 0.000000                      False
# 1           0.125                 0.066667                      False
# 2           0.125                 0.000000                      False
# 3           0.200                 0.466667                       True
# 4           0.150                 0.000000                      False
#
#    BusinessTravel_Travel_Frequently  Department_Human Resources  \
# 0                             False                       False
# 1                              True                       False
# 2                              True                       False
# 3                             False                       False
# 4                             False                       False
#
#    Department_Research & Development  ...  JobSatisfaction_1.0  \
# 0                              False  ...                False
# 1                               True  ...                False
# 2                               True  ...                False
# 3                               True  ...                False
# 4                               True  ...                 True
#
#    JobSatisfaction_2.0  JobSatisfaction_4.0  WorkLifeBalance_1.0  \
# 0                False                 True                False
# 1                 True                False                False
# 2                 True                False                 True
# 3                False                 True                False
# 4                False                False                False
#
#    WorkLifeBalance_3.0  JobInvolvement_1  JobInvolvement_3  JobInvolvement_4  \
# 0                False             False              True             False
# 1                False             False             False             False
# 2                False             False              True             False
# 3                 True             False             False             False
# 4                 True             False              True             False
#
#    Education_2  Education_5
# 0         True        False
# 1        False        False
# 2        False        False
# 3        False         True
# 4        False        False
#
# [5 rows x 30 columns]

# %%
df_new.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'NumCompaniesWorked', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion',
#        'BusinessTravel_Non-Travel', 'BusinessTravel_Travel_Frequently',
#        'Department_Human Resources', 'Department_Research & Development',
#        'Department_Sales', 'JobRole_Healthcare Representative',
#        'JobRole_Laboratory Technician', 'JobRole_Manager',
#        'JobRole_Manufacturing Director', 'JobRole_Research Director',
#        'JobRole_Research Scientist', 'JobRole_Sales Executive',
#        'EnvironmentSatisfaction_1.0', 'EnvironmentSatisfaction_4.0',
#        'JobSatisfaction_1.0', 'JobSatisfaction_2.0', 'JobSatisfaction_4.0',
#        'WorkLifeBalance_1.0', 'WorkLifeBalance_3.0', 'JobInvolvement_1',
#        'JobInvolvement_3', 'JobInvolvement_4', 'Education_2', 'Education_5'],
#       dtype='object')

# %%
dummies = df_new[['BusinessTravel_Non-Travel', 'BusinessTravel_Travel_Frequently',
       'Department_Human Resources', 'Department_Research & Development',
       'Department_Sales', 'JobRole_Healthcare Representative',
       'JobRole_Laboratory Technician', 'JobRole_Manager',
       'JobRole_Manufacturing Director', 'JobRole_Research Director',
       'JobRole_Research Scientist', 'JobRole_Sales Executive',
       'EnvironmentSatisfaction_1.0', 'EnvironmentSatisfaction_4.0',
       'JobSatisfaction_1.0', 'JobSatisfaction_2.0', 'JobSatisfaction_4.0',
       'WorkLifeBalance_1.0', 'WorkLifeBalance_3.0', 'JobInvolvement_1',
       'JobInvolvement_3', 'JobInvolvement_4', 'Education_2', 'Education_5']]

numericas = x_numeric[['Age', 'DistanceFromHome', 'MonthlyIncome', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsSinceLastPromotion']]
numericas
# Out:
#       Age  DistanceFromHome  MonthlyIncome  TrainingTimesLastYear  \
# 0      51                 6         131160                      6
# 1      31                10          41890                      3
# 2      32                17         193280                      2
# 3      38                 2          83210                      5
# 4      32                10          23420                      2
# ...   ...               ...            ...                    ...
# 4303   29                 7          21800                      2
# 4304   33                11          71400                      2
# 4305   33                 1          51470                      2
# 4306   32                23          24680                      2
# 4307   37                 2          40010                      2
#
#       YearsAtCompany  YearsSinceLastPromotion
# 0                  1                        0
# 1                  5                        1
# 2                  5                        0
# 3                  8                        7
# 4                  6                        0
# ...              ...                      ...
# 4303               4                        0
# 4304               5                        0
# 4305               9                        1
# 4306               3                        1
# 4307               1                        0
#
# [4308 rows x 6 columns]

# %%
# Guardar los resultados en archivos CSV
dummies.to_csv('v_cat.csv', index=False)
numericas.to_csv('v_num.csv', index=False)

# Imprimir la ubicación de los archivos generados
print("Los archivos se guardaron como:")
print("v_cat.csv")
print("v_num.csv")
# Out:
# Los archivos se guardaron como:
# v_cat.csv
# v_num.csv

# %% [markdown]
# ## Métodos Integrados

# %% [markdown]
# Regresión Ridge

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso, Ridge

# %%
# Selector con un modelo de regresión logística
sel_ = SelectFromModel(LogisticRegression(penalty='l2', C=1.0))  # Usamos 'l2' para regularización Ridge

sel_.fit(x_num_norm, y)

# Obtener variables seleccionadas
X_new = sel_.get_support()

df_new = x_num.iloc[:, X_new]
print(df_new.head())
